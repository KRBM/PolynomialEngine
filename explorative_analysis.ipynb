# %%
from poly_engine import Polynomial
import numpy as np
import matplotlib.pyplot as plt

# %%
214925525 - 30390200 x + 16486596 x^2 - 1296008 x^3 + 329658 x^4 - 3416 x^5 + 588 x^6 - 8 x^7 + x^8

# %%
f = Polynomial(214925525, -30390200, 16486596, -1296008, 329658, -3416, 588,-8, 1,  name='f')

# %%
print(f)
# Out:
# f(x) = x^8 - 8x^7 + 588x^6 - 3416x^5 + 329658x^4 - 1296008x^3 + 16486596x^2 - 30390200x + 214925525

# %%
f.display_graph(size=(-9, 11))

# %%
r = f.make_reflexsive(2)

# %%
print(r)
print(f == r)
# Out:
# f(x) = x^8 - 8.0x^7 + 588.0x^6 - 3416.0x^5 + 329658.0x^4 - 1296008.0x^3 + 16486596.0x^2 - 30390200.0x + 214925525.0
# True

# %%
f.animate_zeros()
