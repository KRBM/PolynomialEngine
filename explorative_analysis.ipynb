# %%
from poly_engine import Polynomial
import numpy as np
import matplotlib.pyplot as plt

# %%
f = Polynomial(-267100549, -1519126, 765223, -5668, 1427, -6, 1,  name='f')

# %%
print(f)
# Out:
# f(x) = x^6 - 6x^5 + 1427x^4 - 5668x^3 + 765223x^2 - 1519126x - 267100549

# %%
f.display_graph(size=(-9, 11))

# %%
r = f.make_reflexsive(2)

# %%
print(r)
# Out:
# f(x) = x^6 - 6.0x^5 + 1427.0x^4 - 5668.0x^3 + 765223.0x^2 - 1519126.0x - 267100549.0

# %%
f.animate_zeros()
# Out:
# MovieWriter Kasper M unavailable; using Pillow instead.
