# %%
from poly_engine import Polynomial

# %%
f = Polynomial(1, 0, 1)
print(f)
# Out:
# f(x) = x^2 + 1

# %%
g = Polynomial(1, 1, name='g')
print(f)
print(g)
print(f * g)
print(f // g)
# Out:
# f(x) = x^2 + 1
# g(x) = x + 1
# h(x) = x^3 + x^2 + x + 1
# q(x) = x - 1.0

# %%
f.display_graph()

# %%
f.display_zeros()
